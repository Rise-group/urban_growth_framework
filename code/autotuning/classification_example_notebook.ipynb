# %%
#!/usr/bin/python3
# -*- coding: utf-8 -*-
#------------------------------------------------------------------------------------------------------
#Libraries
#------------------------------------------------------------------------------------------------------
import sys
import os
import pandas as pd
import numpy as np
import time
from sklearn import preprocessing

import autotuning

# %%
# Create a random dataset with 4 variables and 100 observations. It is
# important that the dataframe has a label for every variable as the
# process selecets the best features for the model, an identifier is needed
# for each variable.
x_array = np.random.rand(300,4)

df_X = pd.DataFrame(x_array)
df_X.columns = ['var0', 'var1', 'var2', 'var3']

# %%
# We generate random coefficients that will be used to generate the output
coeffs = np.random.rand(1,4)
# Generate the output and add some noise
noise = np.random.rand(300,1) * 2
y_array = np.sum(x_array*coeffs, axis=1).reshape(-1,1) + noise

# Create 3 different classes according to the value they have
class_1 = (y_array > 0.8*2)*1

# Create the output array divided in classes
y_array = class_1

df_y= pd.DataFrame(y_array)
df_y.columns = ['output']

# %%
# You have to past the path and filename to the json file
path_and_filename_to_json_file = 'classification_example_parameters.json'
tic = time.time()
outputs_after_all_iterations = autotuning.get_best_models(
        df_X,
        df_y,
        random_state                    = 42,
        number_of_iterations            = 15,
        compute_higher_order_features   = False,
        use_interaction_features_only   = True,
        degree_of_polynomial            = 2,      
        global_percentage_for_test_size = 0.1,
        local_percentage_for_test_size  = 0.1,
        input_scaler                    = preprocessing.StandardScaler(),
        k_folds                         = 10,
        scoring                         = 'f1_weighted',
        model_type                      = 'classification',
        features_to_eliminate_per_step  = 1,
        verbose_level                   = 0,                    
        number_of_parallel_jobs         = -1,
        parameters_file                 = path_and_filename_to_json_file,
        split_type                      = 'stratified',
        iid                             = False)
toc = time.time()
elapsed_time = toc-tic
print('The whole process took %0.2f seconds = %0.2f minutes = %0.2f hours'\
      % (elapsed_time,elapsed_time/60,elapsed_time/(60*60)))
# Out:
# Iteration #1 out of 15
# Phase 1: Hyperparameter tuning using all features.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.76; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 6, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.81; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 2, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for RandomForestClassifier         are: ['var0', 'var2', 'var3']
# Optimal features for ExtraTreesClassifier           are: ['var0', 'var1', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.66; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 6, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.71; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 2, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.73; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 6, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.73; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 2, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #2 out of 15
# Phase 1: Hyperparameter tuning using all features.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.81; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.85; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# /home/jorge/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Optimal features for RandomForestClassifier         are: ['var0', 'var2', 'var3']
# Optimal features for ExtraTreesClassifier           are: ['var0', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.78; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.79; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.72; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.68; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #3 out of 15
# Phase 1: Hyperparameter tuning using all features.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.86; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.86; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for RandomForestClassifier         are: ['var0', 'var2', 'var3']
# Optimal features for ExtraTreesClassifier           are: ['var0', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.63; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.65; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.79; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.87; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #4 out of 15
# Phase 1: Hyperparameter tuning using all features.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.84; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.89; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for RandomForestClassifier         are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for ExtraTreesClassifier           are: ['var0', 'var1', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.78; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.75; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.68; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.71; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
# Iteration #5 out of 15
# Phase 1: Hyperparameter tuning using all features.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.70; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.73; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for RandomForestClassifier         are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for ExtraTreesClassifier           are: ['var0', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.78; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 6, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.76; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.71; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 6, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.75; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #6 out of 15
# Phase 1: Hyperparameter tuning using all features.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.76; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.78; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for RandomForestClassifier         are: ['var0', 'var2', 'var3']
# Optimal features for ExtraTreesClassifier           are: ['var0', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.79; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 6, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.79; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.83; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 6, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.77; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #7 out of 15
# Phase 1: Hyperparameter tuning using all features.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.82; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 6, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.84; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for RandomForestClassifier         are: ['var0', 'var2', 'var3']
# Optimal features for ExtraTreesClassifier           are: ['var0', 'var1', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.79; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 6, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.79; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.76; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 6, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.79; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #8 out of 15
# Phase 1: Hyperparameter tuning using all features.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.81; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.76; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 2, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for RandomForestClassifier         are: ['var0', 'var2', 'var3']
# Optimal features for ExtraTreesClassifier           are: ['var0', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.79; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.79; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.69; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.77; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #9 out of 15
# Phase 1: Hyperparameter tuning using all features.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.73; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.79; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for RandomForestClassifier         are: ['var0', 'var2', 'var3']
# Optimal features for ExtraTreesClassifier           are: ['var0', 'var1', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.70; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 6, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.72; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.83; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 6, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.80; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #10 out of 15
# Phase 1: Hyperparameter tuning using all features.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.66; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.66; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 2, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for RandomForestClassifier         are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for ExtraTreesClassifier           are: ['var0', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.86; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.86; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.73; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.77; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #11 out of 15
# Phase 1: Hyperparameter tuning using all features.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.72; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.75; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 2, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for RandomForestClassifier         are: ['var0', 'var2', 'var3']
# Optimal features for ExtraTreesClassifier           are: ['var0', 'var1', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.66; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.73; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.71; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.67; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #12 out of 15
# Phase 1: Hyperparameter tuning using all features.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.73; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 6, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.78; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for RandomForestClassifier         are: ['var0', 'var2', 'var3']
# Optimal features for ExtraTreesClassifier           are: ['var0', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.70; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.72; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.90; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.87; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #13 out of 15
# Phase 1: Hyperparameter tuning using all features.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.78; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.85; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for RandomForestClassifier         are: ['var0', 'var2', 'var3']
# Optimal features for ExtraTreesClassifier           are: ['var0', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.79; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 6, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.72; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 2, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.74; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 6, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.74; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 2, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #14 out of 15
# Phase 1: Hyperparameter tuning using all features.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.79; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.76; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 2, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for RandomForestClassifier         are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for ExtraTreesClassifier           are: ['var0', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.79; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 6, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.82; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.74; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 6, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.74; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #15 out of 15
# Phase 1: Hyperparameter tuning using all features.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.63; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 6, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.71; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for RandomForestClassifier         are: ['var0', 'var2', 'var3']
# Optimal features for ExtraTreesClassifier           are: ['var0', 'var1', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting RandomForestClassifier.
# Fitting ExtraTreesClassifier.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.68; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.65; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# f1_weighted = 0.80; RandomForestClassifier.
# Best parameters: {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 5, 'Estimator_RandomForestClassifier__min_samples_split': 4, 'Estimator_RandomForestClassifier__n_estimators': 100}.
#
# f1_weighted = 0.69; ExtraTreesClassifier.
# Best parameters: {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 7, 'Estimator_ExtraTreesClassifier__min_samples_split': 4, 'Estimator_ExtraTreesClassifier__n_estimators': 100}.
# ____________________________________________________________________________________________
#
#
#
# The whole process took 219.64 seconds = 3.66 minutes = 0.06 hours

# %%
# Get the best result for each model
best_pipelines = autotuning.extract_best_pipelines_from_all_iterations(outputs_after_all_iterations)
# Get the best model from the best results
best_pipeline  = autotuning.extract_best_pipeline_from_the_best_models(best_pipelines)

for pipeline in best_pipelines:
    # Each of this pipeline is a prediction class object, so that we can access
    # its attributes
    print()
    print("Pipeline name : {}".format(pipeline.pipeline_name))
    print("The {} value for this model was: {}.".format(pipeline.performance_metric_name,
          pipeline.performance_metric_value))
    print()
    print("Best hyperparameters:")
    print(pipeline.tuned_hyperparameters)
    print()
    print("Optimal features:")
    print(pipeline.names_of_optimal_features)
    print()
    # As this is a classification task, we can print the confusion matrix
    # and the classification report
    print("Confusion Matrix")
    print()
    print(pipeline.confusion_matrix)
    print()
    print("Classification report")
    print(pipeline.classification_report)
    print()
    print("--------------------------------------------------------------")
# Out:
# Pipeline name : RandomForestClassifier
# The f1_weighted value for this model was: 0.9291666666666667.
#
# Best hyperparameters:
# {'Estimator_RandomForestClassifier__class_weight': 'balanced', 'Estimator_RandomForestClassifier__max_depth': 6, 'Estimator_RandomForestClassifier__min_samples_split': 5, 'Estimator_RandomForestClassifier__n_estimators': 100}
#
# Optimal features:
# ['var0', 'var1', 'var2', 'var3']
#
# Confusion Matrix
#
# [[ 5  2]
#  [ 0 23]]
#
# Classification report
#               precision    recall  f1-score   support
#
#            0       1.00      0.71      0.83         7
#            1       0.92      1.00      0.96        23
#
#     accuracy                           0.93        30
#    macro avg       0.96      0.86      0.90        30
# weighted avg       0.94      0.93      0.93        30
#
#
# --------------------------------------------------------------
#
# Pipeline name : ExtraTreesClassifier
# The f1_weighted value for this model was: 0.9291666666666667.
#
# Best hyperparameters:
# {'Estimator_ExtraTreesClassifier__class_weight': 'balanced', 'Estimator_ExtraTreesClassifier__max_depth': 8, 'Estimator_ExtraTreesClassifier__min_samples_split': 2, 'Estimator_ExtraTreesClassifier__n_estimators': 100}
#
# Optimal features:
# ['var0', 'var1', 'var2', 'var3']
#
# Confusion Matrix
#
# [[ 5  2]
#  [ 0 23]]
#
# Classification report
#               precision    recall  f1-score   support
#
#            0       1.00      0.71      0.83         7
#            1       0.92      1.00      0.96        23
#
#     accuracy                           0.93        30
#    macro avg       0.96      0.86      0.90        30
# weighted avg       0.94      0.93      0.93        30
#
#
# --------------------------------------------------------------

# %%
# Graph the performance metric value for each model trough the iterations
autotuning.show_performance_metrics(outputs_after_all_iterations,
                                    name_of_x = 'F1',
                                    title_string = 'Autotuning example with classification',
                                    share_x_axis_among_all_charts = True,
                                    flag_show_plot_in_different_rows = False,
                                    flag_save_figure = False)

# %%
#!/usr/bin/python3
# -*- coding: utf-8 -*-
#------------------------------------------------------------------------------------------------------
#Libraries
#------------------------------------------------------------------------------------------------------
import sys
import os
import pandas as pd
import numpy as np
import time
from sklearn import preprocessing

import autotuning

# %%
# Create a random dataset with 4 variables and 100 observations. It is
# important that the dataframe has a label for every variable as the
# process selecets the best features for the model, an identifier is needed
# for each variable.
x_array = np.random.rand(100,4)

df_X = pd.DataFrame(x_array)
df_X.columns = ['var0', 'var1', 'var2', 'var3']

# %%
# We generate random coefficients that will be used to generate the output
coeffs = np.random.rand(1,4)
# Generate the output and add some noise
noise = np.random.rand(100,1) * 0.48
y_array = np.sum(x_array*coeffs, axis=1).reshape(-1,1) + noise

df_y= pd.DataFrame(y_array)
df_y.columns = ['output']

# %%
# You have to past the path and filename to the json file
path_and_filename_to_json_file = 'regression_example_parameters.json'
tic = time.time()
outputs_after_all_iterations = autotuning.get_best_models(
        df_X,
        df_y,
        random_state                    = 42,
        number_of_iterations            = 20,
        compute_higher_order_features   = False,
        use_interaction_features_only   = True,
        degree_of_polynomial            = 2,      
        global_percentage_for_test_size = 0.1,
        local_percentage_for_test_size  = 0.1,
        input_scaler                    = preprocessing.StandardScaler(),
        k_folds                         = 10,
        scoring                         = 'r2',
        model_type                      = 'regression',
        features_to_eliminate_per_step  = 1,
        verbose_level                   = 0,                    
        number_of_parallel_jobs         = -1,
        parameters_file                 = path_and_filename_to_json_file,
        split_type                      = 'simple',
        iid                             = False)
toc = time.time()
elapsed_time = toc-tic
print('The whole process took %0.2f seconds = %0.2f minutes = %0.2f hours'\
      % (elapsed_time,elapsed_time/60,elapsed_time/(60*60)))
# Out:
# Iteration #1 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.82; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.82; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.73; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Lasso                          are: ['var1', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.76; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.77; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.66; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.64; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.52; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.56; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #2 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.84; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.84; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.85; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.04}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Lasso                          are: ['var0', 'var1', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.81; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.81; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.79; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.82; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.82; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.82; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #3 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.83; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.83; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.79; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.04}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var3']
# Optimal features for Lasso                          are: ['var1', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.69; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.70; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.74; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.82; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.81; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.77; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #4 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.77; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.78; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.87; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Lasso                          are: ['var0', 'var1', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.93; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.93; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.92; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.04}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.90; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.90; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.86; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.04}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #5 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.66; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.67; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.65; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.04}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Lasso                          are: ['var1', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.45; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.46; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.61; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.06}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.94; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.94; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.88; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.06}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #6 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.89; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.89; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.85; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Lasso                          are: ['var1', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.87; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.87; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.77; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.83; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.83; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.71; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #7 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.86; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.86; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.81; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.06}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Lasso                          are: ['var1', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.70; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.70; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.60; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.08}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.62; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.60; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.23; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.08}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #8 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.81; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.81; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.83; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Lasso                          are: ['var1', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.85; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.85; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.74; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.06}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.80; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.80; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.74; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.06}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #9 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.73; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.74; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.77; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Lasso                          are: ['var0', 'var1', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.89; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.89; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.89; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.04}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.87; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.87; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.83; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.04}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #10 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.88; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.88; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.80; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Lasso                          are: ['var0', 'var1', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.93; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.93; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.89; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.91; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.91; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.80; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #11 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.88; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.88; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.86; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.06}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Lasso                          are: ['var1', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.69; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.75; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.64; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.08}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.92; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.90; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.90; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.08}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #12 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.68; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.69; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.78; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.08}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Lasso                          are: ['var1', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.78; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.78; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.82; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.08}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.46; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.46; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.52; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.08}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #13 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.59; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.59; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.52; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.04}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Lasso                          are: ['var0', 'var1', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.69; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.74; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.72; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.08}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.77; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.82; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.78; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.08}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #14 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.81; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.81; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.78; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Lasso                          are: ['var1', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.61; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.62; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.67; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.04}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.92; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.92; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.85; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.04}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #15 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.88; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.88; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.82; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Lasso                          are: ['var0', 'var1', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.88; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.88; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.84; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.83; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.82; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.78; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #16 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.93; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.93; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.90; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Lasso                          are: ['var1', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.82; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.82; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.80; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.06}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.90; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.90; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.89; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.06}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #17 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.82; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.82; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.79; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Lasso                          are: ['var1', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.81; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.81; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.81; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.04}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.93; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.93; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.88; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.04}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #18 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.88; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.88; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.81; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var3']
# Optimal features for Lasso                          are: ['var0', 'var1', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.79; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.79; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.77; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.72; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.72; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.66; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #19 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.79; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.79; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.84; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.04}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Lasso                          are: ['var1', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.50; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.55; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.63; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.08}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.64; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.72; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.58; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.08}.
# ____________________________________________________________________________________________
#
#
#
# Iteration #20 out of 20
# Phase 1: Hyperparameter tuning using all features.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.87; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.87; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.85; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.04}.
# ____________________________________________________________________________________________
#
#
#
# Phase 2: Recursive feature elimination using best hyperparameters.
# ____________________________________________________________________________________________
# Summary of recursive feature elimination
# ____________________________________________________________________________________________
# Optimal features for LinearRegression               are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Ridge                          are: ['var0', 'var1', 'var2', 'var3']
# Optimal features for Lasso                          are: ['var0', 'var1', 'var2', 'var3']
# ____________________________________________________________________________________________
#
#
# Phase 3: Hyperparamter tuning using only the optimal features               for each model.
# Fitting LinearRegression.
# Fitting Ridge.
# Fitting Lasso.
# ____________________________________________________________________________________________
# Prediction performance  (LOCAL test set)
# ____________________________________________________________________________________________
# r2 = 0.85; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.85; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.79; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# Phase 4: Extracting performance metrics for the test set.
# ____________________________________________________________________________________________
# Prediction performance  (GLOBAL test set)
# ____________________________________________________________________________________________
# r2 = 0.88; LinearRegression.
# Best parameters: {'Estimator_LinearRegression__fit_intercept': True}.
#
# r2 = 0.87; Ridge.
# Best parameters: {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}.
#
# r2 = 0.80; Lasso.
# Best parameters: {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.02}.
# ____________________________________________________________________________________________
#
#
#
# The whole process took 28.62 seconds = 0.48 minutes = 0.01 hours

# %%
# Get the best result for each model
best_pipelines = autotuning.extract_best_pipelines_from_all_iterations(outputs_after_all_iterations)
# Get the best model from the best results
best_pipeline  = autotuning.extract_best_pipeline_from_the_best_models(best_pipelines)

for pipeline in best_pipelines:
    # Each of this pipeline is a prediction class object, so that we can access
    # its attributes
    print()
    print("Pipeline name : {}".format(pipeline.pipeline_name))
    print("The {} value for this model was: {}.".format(pipeline.performance_metric_name,
          pipeline.performance_metric_value))
    print()
    print("Best hyperparameters:")
    print(pipeline.tuned_hyperparameters)
    print()
    print("Optimal features:")
    print(pipeline.names_of_optimal_features)
    print()
    print("--------------------------------------------------------------")
# Out:
# Pipeline name : LinearRegression
# The r2 value for this model was: 0.9362168253402616.
#
# Best hyperparameters:
# {'Estimator_LinearRegression__fit_intercept': True}
#
# Optimal features:
# ['var0', 'var1', 'var2', 'var3']
#
# --------------------------------------------------------------
#
# Pipeline name : Ridge
# The r2 value for this model was: 0.9372964022227372.
#
# Best hyperparameters:
# {'Estimator_Ridge__alpha': 0.9, 'Estimator_Ridge__fit_intercept': True}
#
# Optimal features:
# ['var0', 'var1', 'var2', 'var3']
#
# --------------------------------------------------------------
#
# Pipeline name : Lasso
# The r2 value for this model was: 0.8955080187785247.
#
# Best hyperparameters:
# {'Estimator_Lasso__alpha': 0.03, 'Estimator_Lasso__fit_intercept': True, 'Estimator_Lasso__max_iter': 10000, 'Estimator_Lasso__tol': 0.08}
#
# Optimal features:
# ['var1', 'var3']
#
# --------------------------------------------------------------

# %%
autotuning.show_performance_metrics(outputs_after_all_iterations,
                                    name_of_x = 'R2',
                                    title_string = 'Autotuning example with regression',
                                    share_x_axis_among_all_charts = True,
                                    flag_show_plot_in_different_rows = True,
                                    flag_save_figure = False)
